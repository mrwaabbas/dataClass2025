# %% [markdown]
# # Homework for Week 6
#
# The goal for this homework is to see the relevant journalistic uses for what we learned in class.
#
# 1. Ingest different types of spreadsheets into Pandas,
# 2. Gather general info about our dataframes
# 3. Target specific values

# %% [markdown]
# ## Pandas - Importing data
#
# Please download the following data and move it to an appropriate folder on your computer:
#
# - <a href="https://github.com/sandeepmj/datasets/blob/main/importing-excerpts/ems20_1st_6months_excerpt.csv">EMS excerpt</a>,
#
# - <a href="https://github.com/sandeepmj/datasets/blob/main/importing-excerpts/multi-data.xlsx">Customs, Border Patrol</a>
#
# **Give yourself time to download it. Some of the files are large!**

# %%
## import the pandas library in this cell

import pandas as pd

# %% [markdown]
# ### Ingest the following dataset into this note:
#
# - ```ems20_1st_6months_excerpt.csv``` into a dataframe named ```ems2020_excerpt_df```

# %%
## import data and store in dataframe
df = pd.read_csv("data-rawhomework/ems20_1st_6months_excerpt.csv")

# %%
## call the first 10 rows
df.head(10)
# Out:
#    CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0        201101264  2020-04-19 10:25:47            INJMIN
# 1        200423766  2020-02-11 19:25:47              CARD
# 2        200434110  2020-02-12 21:36:52               UNC
# 3        201610121  2020-06-09 00:52:30              DRUG
# 4        200034112  2020-01-03 20:44:05              DRUG
# 5        200530247  2020-02-22 01:26:18              DRUG
# 6        200543279  2020-02-23 19:08:27               UNC
# 7        201471743  2020-05-26 12:45:46            INJURY
# 8        201180116  2020-04-27 00:57:48               EDP
# 9        200572739  2020-02-26 15:15:25            CARDBR
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            7          INJMIN                          7
# 1                            3            SICK                          6
# 2                            2             UNC                          2
# 3                            4            DRUG                          4
# 4                            4            DRUG                          4
# 5                            4            DRUG                          4
# 6                            2             UNC                          2
# 7                            5          INJURY                          5
# 8                            7            EDPC                          7
# 9                            2          CARDBR                          2
#
#   FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 0    04/19/2020 10:26:24 AM                              Y
# 1    02/11/2020 07:25:56 PM                              Y
# 2    02/12/2020 09:37:24 PM                              Y
# 3    06/09/2020 12:52:44 AM                              Y
# 4    01/03/2020 08:44:11 PM                              Y
# 5    02/22/2020 01:27:21 AM                              Y
# 6    02/23/2020 07:08:44 PM                              Y
# 7    05/26/2020 12:46:04 PM                              Y
# 8    04/27/2020 12:58:07 AM                              Y
# 9    02/26/2020 03:16:35 PM                              Y
#
#    DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT  \
# 0                            37    04/19/2020 10:26:24 AM  ...           40.0
# 1                             9    02/11/2020 07:26:09 PM  ...           52.0
# 2                            32    02/12/2020 09:38:27 PM  ...          106.0
# 3                            14    06/09/2020 12:52:59 AM  ...           19.0
# 4                             6    01/03/2020 08:44:17 PM  ...           66.0
# 5                            63    02/22/2020 01:27:41 AM  ...           25.0
# 6                            17    02/23/2020 07:09:16 PM  ...           44.0
# 7                            18    05/26/2020 12:46:15 PM  ...           41.0
# 8                            19    04/27/2020 12:58:15 AM  ...           50.0
# 9                            70    02/26/2020 03:16:49 PM  ...          106.0
#
#   CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT  \
# 0                 8.0              201.0                      7.0
# 1                14.0              207.0                     10.0
# 2                32.0              410.0                     27.0
# 3                 4.0              108.0                      2.0
# 4                39.0              312.0                     15.0
# 5                 8.0              111.0                      4.0
# 6                 8.0              204.0                      9.0
# 7                17.0              202.0                      8.0
# 8                11.0              208.0                     10.0
# 9                28.0              410.0                     27.0
#
#   CONGRESSIONALDISTRICT REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR  \
# 0                  15.0                N                       N
# 1                  15.0                N                       N
# 2                   8.0                N                       N
# 3                  12.0                N                       N
# 4                   7.0                N                       N
# 5                  12.0                N                       N
# 6                  15.0                N                       N
# 7                  15.0                N                       N
# 8                  16.0                N                       N
# 9                   5.0                N                       N
#
#   STANDBY_INDICATOR  TRANSFER_INDICATOR        source
# 0                 N                   N  chunk170.csv
# 1                 N                   N  chunk166.csv
# 2                 N                   N  chunk166.csv
# 3                 N                   N  chunk171.csv
# 4                 N                   N  chunk165.csv
# 5                 N                   N  chunk167.csv
# 6                 N                   N  chunk167.csv
# 7                 N                   N  chunk171.csv
# 8                 N                   N  chunk170.csv
# 9                 N                   N  chunk167.csv
#
# [10 rows x 32 columns]

# %%
## call the last 5 rows
df.tail()
# Out:
#        CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 13112        200393407  2020-02-08 19:49:33            DIFFBR
# 13113        200034618  2020-01-03 22:51:33            INJURY
# 13114        200424355  2020-02-11 21:51:09              SICK
# 13115        201742708  2020-06-22 15:57:44            MVAINJ
# 13116        200865674  2020-03-26 19:33:19            DIFFFC
#
#        INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 13112                            2          DIFFBR                          2
# 13113                            5          INJURY                          5
# 13114                            6            SICK                          6
# 13115                            4          MVAINJ                          4
# 13116                            2          DIFFFC                          2
#
#       FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 13112    02/08/2020 07:52:34 PM                              Y
# 13113    01/03/2020 10:51:39 PM                              Y
# 13114    02/11/2020 09:52:09 PM                              Y
# 13115    06/22/2020 03:58:07 PM                              Y
# 13116    03/26/2020 07:33:50 PM                              Y
#
#        DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  ...  \
# 13112                           181    02/08/2020 07:53:00 PM  ...
# 13113                             6    01/03/2020 10:52:21 PM  ...
# 13114                            60    02/11/2020 09:52:18 PM  ...
# 13115                            23    06/22/2020 03:58:19 PM  ...
# 13116                            31    03/26/2020 07:34:08 PM  ...
#
#       POLICEPRECINCT CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  \
# 13112           72.0                38.0              307.0
# 13113           75.0                42.0              305.0
# 13114           48.0                15.0              206.0
# 13115           62.0                47.0              311.0
# 13116          103.0                27.0              412.0
#
#        COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT REOPEN_INDICATOR  \
# 13112                     15.0                   7.0                N
# 13113                     19.0                   8.0                N
# 13114                     10.0                  15.0                N
# 13115                     21.0                  11.0                N
# 13116                     29.0                   5.0                N
#
#       SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  TRANSFER_INDICATOR  \
# 13112                       N                 N                   N
# 13113                       N                 N                   N
# 13114                       N                 N                   N
# 13115                       N                 N                   N
# 13116                       N                 N                   N
#
#              source
# 13112  chunk166.csv
# 13113  chunk165.csv
# 13114  chunk166.csv
# 13115  chunk172.csv
# 13116  chunk168.csv
#
# [5 rows x 32 columns]

# %%
## call a 20 random rows
df.sample(20)
# Out:
#        CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 3568         200090495  2020-01-09 04:54:44             MCI21
# 5544         201015292  2020-04-10 23:39:31            SICKFC
# 9881         200431432  2020-02-12 10:40:36            MVAINJ
# 4320         200393960  2020-02-08 22:07:38            RESPIR
# 8067         200651712  2020-03-05 11:38:33            DIFFBR
# 6755         201051104  2020-04-14 08:28:38            ARREST
# 4484         200803326  2020-03-20 16:03:41              SICK
# 3886         200750863  2020-03-15 05:00:41            RESPIR
# 575          200422997  2020-02-11 15:59:02            INJMAJ
# 4512         201073431  2020-04-16 19:31:33            DIFFFC
# 4222         200191883  2020-01-19 12:19:44            ALTMEN
# 6857         201731499  2020-06-21 10:59:18            STATEP
# 10999        201652559  2020-06-13 17:21:58               CVA
# 6497         200642860  2020-03-04 16:01:26               UNC
# 2408         201211318  2020-04-30 11:40:07            ALTMFC
# 8315         200222983  2020-01-22 16:21:12              SICK
# 2504         200042611  2020-01-04 15:27:31            UNKNOW
# 4418         201632640  2020-06-11 17:06:43            UNKNOW
# 8836         200122661  2020-01-12 15:33:12              SICK
# 11776        200411149  2020-02-10 08:51:28            UNKNOW
#
#        INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 3568                             2           MCI21                          2
# 5544                             6          SICKFC                          6
# 9881                             4          MVAINJ                          4
# 4320                             4          RESPIR                          4
# 8067                             2          DIFFBR                          2
# 6755                             1          ARREST                          1
# 4484                             6            SICK                          6
# 3886                             4          RESPIR                          4
# 575                              3          INJMAJ                          3
# 4512                             2            SICK                          6
# 4222                             3          ALTMEN                          3
# 6857                             2          STATEP                          2
# 10999                            4             CVA                          4
# 6497                             2             UNC                          2
# 2408                             3          ALTMFC                          3
# 8315                             6            SICK                          6
# 2504                             4          UNKNOW                          4
# 4418                             4          UNKNOW                          4
# 8836                             6            SICK                          6
# 11776                            4          UNKNOW                          4
#
#       FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 3568     01/09/2020 04:54:55 AM                              Y
# 5544     04/11/2020 12:55:40 AM                              Y
# 9881     02/12/2020 10:42:11 AM                              Y
# 4320     02/08/2020 10:08:08 PM                              Y
# 8067     03/05/2020 11:38:56 AM                              Y
# 6755     04/14/2020 08:28:46 AM                              Y
# 4484     03/20/2020 05:06:42 PM                              Y
# 3886     03/15/2020 05:00:52 AM                              Y
# 575      02/11/2020 03:59:14 PM                              Y
# 4512     04/16/2020 07:32:59 PM                              Y
# 4222     01/19/2020 12:20:07 PM                              Y
# 6857     06/21/2020 10:59:26 AM                              Y
# 10999    06/13/2020 05:22:08 PM                              Y
# 6497     03/04/2020 04:01:31 PM                              Y
# 2408     04/30/2020 11:40:11 AM                              Y
# 8315     01/22/2020 04:21:19 PM                              Y
# 2504     01/04/2020 03:28:05 PM                              Y
# 4418     06/11/2020 05:06:54 PM                              Y
# 8836     01/12/2020 03:33:23 PM                              Y
# 11776    02/10/2020 08:51:36 AM                              Y
#
#        DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  ...  \
# 3568                             11    01/09/2020 04:55:13 AM  ...
# 5544                           4569    04/11/2020 12:55:59 AM  ...
# 9881                             95    02/12/2020 10:42:28 AM  ...
# 4320                             30    02/08/2020 10:08:31 PM  ...
# 8067                             23    03/05/2020 11:39:11 AM  ...
# 6755                              8    04/14/2020 08:29:11 AM  ...
# 4484                           3781    03/20/2020 05:08:28 PM  ...
# 3886                             11    03/15/2020 05:01:08 AM  ...
# 575                              12    02/11/2020 03:59:32 PM  ...
# 4512                             86    04/16/2020 07:33:13 PM  ...
# 4222                             23    01/19/2020 12:20:31 PM  ...
# 6857                              8    06/21/2020 10:59:36 AM  ...
# 10999                            10    06/13/2020 05:22:40 PM  ...
# 6497                              5    03/04/2020 04:01:54 PM  ...
# 2408                              4    04/30/2020 11:40:23 AM  ...
# 8315                              7    01/22/2020 04:22:19 PM  ...
# 2504                             34    01/04/2020 03:28:24 PM  ...
# 4418                             11    06/11/2020 05:07:07 PM  ...
# 8836                             11    01/12/2020 03:33:43 PM  ...
# 11776                             8    02/10/2020 08:51:47 AM  ...
#
#       POLICEPRECINCT CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  \
# 3568            75.0                42.0              305.0
# 5544            46.0                15.0              205.0
# 9881           113.0                28.0              412.0
# 4320            70.0                45.0              314.0
# 8067           100.0                31.0              414.0
# 6755            47.0                12.0              212.0
# 4484            40.0                 8.0              201.0
# 3886            75.0                42.0              305.0
# 575             75.0                42.0              305.0
# 4512           108.0                26.0              402.0
# 4222            60.0                47.0              313.0
# 6857            61.0                48.0              315.0
# 10999           70.0                40.0              314.0
# 6497            66.0                44.0              312.0
# 2408           113.0                27.0              412.0
# 8315            84.0                33.0              302.0
# 2504             NaN                 NaN                NaN
# 4418            70.0                44.0              314.0
# 8836           120.0                49.0              501.0
# 11776          109.0                19.0              407.0
#
#        COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT REOPEN_INDICATOR  \
# 3568                      19.0                   8.0                N
# 5544                       9.0                  15.0                Y
# 9881                      27.0                   5.0                N
# 4320                      22.0                   9.0                N
# 8067                      27.0                   5.0                N
# 6755                      11.0                  16.0                N
# 4484                       7.0                  15.0                N
# 3886                      19.0                   8.0                N
# 575                       19.0                   8.0                N
# 4512                      30.0                  14.0                N
# 4222                      21.0                  11.0                N
# 6857                      22.0                   9.0                N
# 10999                     22.0                   9.0                N
# 6497                      20.0                  10.0                N
# 2408                      29.0                   5.0                N
# 8315                      13.0                   7.0                N
# 2504                       NaN                   NaN                N
# 4418                      22.0                   9.0                N
# 8836                      31.0                  11.0                N
# 11776                     25.0                  14.0                N
#
#       SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  TRANSFER_INDICATOR  \
# 3568                        N                 N                   N
# 5544                        N                 N                   N
# 9881                        N                 N                   N
# 4320                        N                 N                   N
# 8067                        N                 N                   N
# 6755                        N                 N                   N
# 4484                        N                 N                   N
# 3886                        N                 N                   N
# 575                         N                 N                   N
# 4512                        N                 N                   N
# 4222                        N                 N                   N
# 6857                        N                 N                   N
# 10999                       N                 N                   N
# 6497                        N                 N                   N
# 2408                        N                 N                   N
# 8315                        N                 N                   N
# 2504                        N                 N                   N
# 4418                        N                 N                   N
# 8836                        N                 N                   N
# 11776                       N                 N                   N
#
#              source
# 3568   chunk165.csv
# 5544   chunk169.csv
# 9881   chunk166.csv
# 4320   chunk166.csv
# 8067   chunk167.csv
# 6755   chunk169.csv
# 4484   chunk168.csv
# 3886   chunk168.csv
# 575    chunk166.csv
# 4512   chunk169.csv
# 4222   chunk165.csv
# 6857   chunk172.csv
# 10999  chunk171.csv
# 6497   chunk167.csv
# 2408   chunk170.csv
# 8315   chunk166.csv
# 2504   chunk165.csv
# 4418   chunk171.csv
# 8836   chunk165.csv
# 11776  chunk166.csv
#
# [20 rows x 32 columns]

# %%
## get basic overview of the data
## what datatypes do the different columns hold?
## how many rows and columns are there

# %%
## basic overview of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13117 entries, 0 to 13116
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   CAD_INCIDENT_ID                 13117 non-null  int64
#  1   INCIDENT_DATETIME               13117 non-null  object
#  2   INITIAL_CALL_TYPE               13117 non-null  object
#  3   INITIAL_SEVERITY_LEVEL_CODE     13117 non-null  int64
#  4   FINAL_CALL_TYPE                 13117 non-null  object
#  5   FINAL_SEVERITY_LEVEL_CODE       13117 non-null  int64
#  6   FIRST_ASSIGNMENT_DATETIME       13010 non-null  object
#  7   VALID_DISPATCH_RSPNS_TIME_INDC  13117 non-null  object
#  8   DISPATCH_RESPONSE_SECONDS_QY    13117 non-null  int64
#  9   FIRST_ACTIVATION_DATETIME       12988 non-null  object
#  10  FIRST_ON_SCENE_DATETIME         12533 non-null  object
#  11  VALID_INCIDENT_RSPNS_TIME_INDC  13117 non-null  object
#  12  INCIDENT_RESPONSE_SECONDS_QY    12533 non-null  float64
#  13  INCIDENT_TRAVEL_TM_SECONDS_QY   12533 non-null  float64
#  14  FIRST_TO_HOSP_DATETIME          7870 non-null   object
#  15  FIRST_HOSP_ARRIVAL_DATETIME     7791 non-null   object
#  16  INCIDENT_CLOSE_DATETIME         13110 non-null  object
#  17  HELD_INDICATOR                  13117 non-null  object
#  18  INCIDENT_DISPOSITION_CODE       12985 non-null  float64
#  19  BOROUGH                         13117 non-null  object
#  20  INCIDENT_DISPATCH_AREA          13117 non-null  object
#  21  ZIPCODE                         12987 non-null  float64
#  22  POLICEPRECINCT                  12988 non-null  float64
#  23  CITYCOUNCILDISTRICT             12988 non-null  float64
#  24  COMMUNITYDISTRICT               12988 non-null  float64
#  25  COMMUNITYSCHOOLDISTRICT         12978 non-null  float64
#  26  CONGRESSIONALDISTRICT           12988 non-null  float64
#  27  REOPEN_INDICATOR                13117 non-null  object
#  28  SPECIAL_EVENT_INDICATOR         13117 non-null  object
#  29  STANDBY_INDICATOR               13117 non-null  object
#  30  TRANSFER_INDICATOR              13117 non-null  object
#  31  source                          13117 non-null  object
# dtypes: float64(9), int64(4), object(19)
# memory usage: 3.2+ MB

# %%
## call the top 7 rows
df.head(7)
# Out:
#    CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0        201101264  2020-04-19 10:25:47            INJMIN
# 1        200423766  2020-02-11 19:25:47              CARD
# 2        200434110  2020-02-12 21:36:52               UNC
# 3        201610121  2020-06-09 00:52:30              DRUG
# 4        200034112  2020-01-03 20:44:05              DRUG
# 5        200530247  2020-02-22 01:26:18              DRUG
# 6        200543279  2020-02-23 19:08:27               UNC
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            7          INJMIN                          7
# 1                            3            SICK                          6
# 2                            2             UNC                          2
# 3                            4            DRUG                          4
# 4                            4            DRUG                          4
# 5                            4            DRUG                          4
# 6                            2             UNC                          2
#
#   FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 0    04/19/2020 10:26:24 AM                              Y
# 1    02/11/2020 07:25:56 PM                              Y
# 2    02/12/2020 09:37:24 PM                              Y
# 3    06/09/2020 12:52:44 AM                              Y
# 4    01/03/2020 08:44:11 PM                              Y
# 5    02/22/2020 01:27:21 AM                              Y
# 6    02/23/2020 07:08:44 PM                              Y
#
#    DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT  \
# 0                            37    04/19/2020 10:26:24 AM  ...           40.0
# 1                             9    02/11/2020 07:26:09 PM  ...           52.0
# 2                            32    02/12/2020 09:38:27 PM  ...          106.0
# 3                            14    06/09/2020 12:52:59 AM  ...           19.0
# 4                             6    01/03/2020 08:44:17 PM  ...           66.0
# 5                            63    02/22/2020 01:27:41 AM  ...           25.0
# 6                            17    02/23/2020 07:09:16 PM  ...           44.0
#
#   CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT  \
# 0                 8.0              201.0                      7.0
# 1                14.0              207.0                     10.0
# 2                32.0              410.0                     27.0
# 3                 4.0              108.0                      2.0
# 4                39.0              312.0                     15.0
# 5                 8.0              111.0                      4.0
# 6                 8.0              204.0                      9.0
#
#   CONGRESSIONALDISTRICT REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR  \
# 0                  15.0                N                       N
# 1                  15.0                N                       N
# 2                   8.0                N                       N
# 3                  12.0                N                       N
# 4                   7.0                N                       N
# 5                  12.0                N                       N
# 6                  15.0                N                       N
#
#   STANDBY_INDICATOR  TRANSFER_INDICATOR        source
# 0                 N                   N  chunk170.csv
# 1                 N                   N  chunk166.csv
# 2                 N                   N  chunk166.csv
# 3                 N                   N  chunk171.csv
# 4                 N                   N  chunk165.csv
# 5                 N                   N  chunk167.csv
# 6                 N                   N  chunk167.csv
#
# [7 rows x 32 columns]

# %%
## call a sample of 10
df.sample(10)
# Out:
#        CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 12191        200362135  2020-02-05 13:07:14              SICK
# 2554         201382834  2020-05-17 19:19:05             OBMAJ
# 1393         201573612  2020-06-05 20:49:48            ASTHMB
# 3352         201034508  2020-04-12 22:32:45            INJURY
# 10982        201241988  2020-05-03 14:49:46               EDP
# 10545        201701233  2020-06-18 10:59:15               UNC
# 12055        200463507  2020-02-15 20:20:42            ARREST
# 6274         200182128  2020-01-18 13:44:30              SICK
# 6117         200511149  2020-02-20 09:41:30              CARD
# 4144         200500476  2020-02-19 03:55:29               EDP
#
#        INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 12191                            6            SICK                          6
# 2554                             3           OBMAJ                          3
# 1393                             2          ASTHMB                          2
# 3352                             5          INJURY                          5
# 10982                            7             EDP                          7
# 10545                            2             UNC                          2
# 12055                            1          ARREST                          1
# 6274                             6            SICK                          6
# 6117                             3            CARD                          3
# 4144                             7            EDPC                          7
#
#       FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 12191    02/05/2020 01:07:38 PM                              Y
# 2554     05/17/2020 07:19:14 PM                              Y
# 1393     06/05/2020 08:50:10 PM                              Y
# 3352     04/12/2020 10:32:57 PM                              Y
# 10982    05/03/2020 02:50:08 PM                              Y
# 10545    06/18/2020 10:59:32 AM                              Y
# 12055    02/15/2020 08:21:08 PM                              Y
# 6274     01/18/2020 01:45:13 PM                              Y
# 6117     02/20/2020 09:41:43 AM                              Y
# 4144     02/19/2020 03:55:40 AM                              Y
#
#        DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  ...  \
# 12191                            24    02/05/2020 01:08:31 PM  ...
# 2554                              9    05/17/2020 07:19:19 PM  ...
# 1393                             22    06/05/2020 08:50:19 PM  ...
# 3352                             12    04/12/2020 10:33:14 PM  ...
# 10982                            22    05/03/2020 02:50:47 PM  ...
# 10545                            17    06/18/2020 10:59:51 AM  ...
# 12055                            26    02/15/2020 08:22:26 PM  ...
# 6274                             43    01/18/2020 01:45:37 PM  ...
# 6117                             13    02/20/2020 09:41:49 AM  ...
# 4144                             11    02/19/2020 03:55:42 AM  ...
#
#       POLICEPRECINCT CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  \
# 12191           44.0                16.0              204.0
# 2554            48.0                17.0              206.0
# 1393           100.0                32.0              414.0
# 3352            72.0                38.0              307.0
# 10982           71.0                35.0              309.0
# 10545           49.0                12.0              211.0
# 12055           81.0                36.0              303.0
# 6274            90.0                34.0              301.0
# 6117            46.0                15.0              205.0
# 4144            90.0                34.0              301.0
#
#        COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT REOPEN_INDICATOR  \
# 12191                      9.0                  15.0                N
# 2554                      12.0                  15.0                N
# 1393                      27.0                   5.0                N
# 3352                      15.0                   7.0                N
# 10982                     17.0                   9.0                N
# 10545                     11.0                  16.0                N
# 12055                     16.0                   8.0                N
# 6274                      14.0                   7.0                N
# 6117                      10.0                  15.0                N
# 4144                      14.0                   7.0                N
#
#       SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  TRANSFER_INDICATOR  \
# 12191                       N                 N                   N
# 2554                        N                 N                   N
# 1393                        N                 N                   N
# 3352                        N                 N                   N
# 10982                       N                 N                   N
# 10545                       N                 N                   N
# 12055                       N                 N                   N
# 6274                        N                 N                   N
# 6117                        N                 N                   N
# 4144                        N                 N                   N
#
#              source
# 12191  chunk166.csv
# 2554   chunk171.csv
# 1393   chunk171.csv
# 3352   chunk169.csv
# 10982  chunk170.csv
# 10545  chunk172.csv
# 12055  chunk167.csv
# 6274   chunk165.csv
# 6117   chunk167.csv
# 4144   chunk167.csv
#
# [10 rows x 32 columns]

# %%
## call the bottom 6
df.tail(6)
# Out:
#        CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 13111        200870168  2020-03-27 00:42:59            INJURY
# 13112        200393407  2020-02-08 19:49:33            DIFFBR
# 13113        200034618  2020-01-03 22:51:33            INJURY
# 13114        200424355  2020-02-11 21:51:09              SICK
# 13115        201742708  2020-06-22 15:57:44            MVAINJ
# 13116        200865674  2020-03-26 19:33:19            DIFFFC
#
#        INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 13111                            5          INJURY                          5
# 13112                            2          DIFFBR                          2
# 13113                            5          INJURY                          5
# 13114                            6            SICK                          6
# 13115                            4          MVAINJ                          4
# 13116                            2          DIFFFC                          2
#
#       FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 13111    03/27/2020 12:43:13 AM                              Y
# 13112    02/08/2020 07:52:34 PM                              Y
# 13113    01/03/2020 10:51:39 PM                              Y
# 13114    02/11/2020 09:52:09 PM                              Y
# 13115    06/22/2020 03:58:07 PM                              Y
# 13116    03/26/2020 07:33:50 PM                              Y
#
#        DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  ...  \
# 13111                            14    03/27/2020 12:43:28 AM  ...
# 13112                           181    02/08/2020 07:53:00 PM  ...
# 13113                             6    01/03/2020 10:52:21 PM  ...
# 13114                            60    02/11/2020 09:52:18 PM  ...
# 13115                            23    06/22/2020 03:58:19 PM  ...
# 13116                            31    03/26/2020 07:34:08 PM  ...
#
#       POLICEPRECINCT CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  \
# 13111          109.0                19.0              407.0
# 13112           72.0                38.0              307.0
# 13113           75.0                42.0              305.0
# 13114           48.0                15.0              206.0
# 13115           62.0                47.0              311.0
# 13116          103.0                27.0              412.0
#
#        COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT REOPEN_INDICATOR  \
# 13111                     25.0                   3.0                N
# 13112                     15.0                   7.0                N
# 13113                     19.0                   8.0                N
# 13114                     10.0                  15.0                N
# 13115                     21.0                  11.0                N
# 13116                     29.0                   5.0                N
#
#       SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  TRANSFER_INDICATOR  \
# 13111                       N                 N                   N
# 13112                       N                 N                   N
# 13113                       N                 N                   N
# 13114                       N                 N                   N
# 13115                       N                 N                   N
# 13116                       N                 N                   N
#
#              source
# 13111  chunk168.csv
# 13112  chunk166.csv
# 13113  chunk165.csv
# 13114  chunk166.csv
# 13115  chunk172.csv
# 13116  chunk168.csv
#
# [6 rows x 32 columns]

# %%
## Programmatically capture the 2245th FINAL_CALL_TYPE value and store in a variable.
call = cbp_df.iloc[2245]["FINAL_CALL_TYPE"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FINAL_CALL_TYPE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 2
#       1 ## Programmatically capture the 2245th FINAL_CALL_TYPE value and store in a variable.
# ----> 2 call = cbp_df.iloc[2245]["FINAL_CALL_TYPE"]
#       3 print(call)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'FINAL_CALL_TYPE'

# %% [markdown]
# ## Targeting an Excel sheet
#
# Use the Customs and Border Protection data in this ```multi-data.xlsx``` workbook to answer the following questions.
#
# Create a dataframe called ```cbp_df```.

# %%
## import data here
cbp_df = pd.read_excel("data-rawhomework/CBP.xlsx")

# %%
## call the top 15 rows

cbp_df.head(15)
# Out:
#     Serial Number      County License Type Code License Class Code  \
# 0         2000777      ALBANY                HL                242
# 1         1197749      NASSAU                CT                246
# 2         2149537    SULLIVAN                AX                122
# 3         1311950      QUEENS                 W                322
# 4         2217319      PUTNAM                TW                344
# 5         1319511    NEW YORK                RW                341
# 6         2220767  MONTGOMERY                 C                103
# 7         2129283      ALBANY                WS                308
# 8         2138381      ALBANY                WS                308
# 9         2160505      ALBANY                WS                308
# 10        2175892      ALBANY                WS                308
# 11        2188886      ALBANY                WS                308
# 12        2192454      ALBANY                WS                308
# 13        1286881    NEW YORK                OP                252
# 14        1289791       BRONX                AX                122
#
#     Certificate Number                   Premise Name                     DBA  \
# 0               912771          SUPER HOST HOTELS INC     ALBANY RAMADA PLAZA
# 1               913036          MEMORARE CATERERS INC                     NaN
# 2               910149              AHMED TRADING INC                     NaN
# 3               903719                    CAOTICO LLC             FORET WINES
# 4               917985           COFFEE TIME CAFE INC                     NaN
# 5               831035  DONATELLA MOXY 7TH AVENUE LLC         PROVA PIZZA BAR
# 6               935317              CUDA BEVERAGE LLC         BILL'S BEVERAGE
# 7               911084       SILVERADO VINEYARDS, THE                     NaN
# 8               911310          VOLCANO VINEYARDS LLC          VOLCANO WINERY
# 9               911278            J J COHN ESTATE LLC                     NaN
# 10              911215    KENEFICK RANCHES WINERY LLC   KENEFICK RANCH WINERY
# 11              909969                       KSSM LLC    MICHAEL SCHLUMBERGER
# 12              918967     TERRAVANT WINE COMPANY LLC  TERRAVANT WINE COMPANY
# 13              913420                 MERMAID 88 LLC         THE MERMAID INN
# 14              912566     NEW FORDHAM FOOD PLAZA INC                     NaN
#
#            Premise Address           Premise Address 2    Premise City  ...  \
# 0         3 WATERVLIET AVE                         NaN          ALBANY  ...
# 1       2183 JACKSON AVE A  WAVERLY AVE & MERRICK ROAD         SEAFORD  ...
# 2      1302 STATE ROUTE 52                         NaN  LOCH SHELDRAKE  ...
# 3         68-38 FOREST AVE                STOREFRONT C       RIDGEWOOD  ...
# 4               559 RTE 6N                         NaN         MAHOPAC  ...
# 5              485 7TH AVE                GROUND FLOOR        NEW YORK  ...
# 6              1 WILLOW ST                         NaN       AMSTERDAM  ...
# 7     6121 SILVERADO TRAIL                         NaN            NAPA  ...
# 8        35 PILMAUNA DRIVE                         NaN         VOLCANO  ...
# 9          5055 SOLANO AVE                  7079689367            NAPA  ...
# 10    4550 SILVERADO TRAIL                         NaN       CALISTOGA  ...
# 11      4155 WINE CREEK RD                         NaN      HEALDSBURG  ...
# 12  35 & 70 INDUSTRIAL WAY                         NaN        BUELLTON  ...
# 13   570-572 AMSTERDAM AVE                         NaN        NEW YORK  ...
# 14        2487 CRESTON AVE                         NaN           BRONX  ...
#
#    Premise Zip License Issued Date License Expiration Date  \
# 0        12206          2019-11-15              2021-11-30
# 1        11783          2019-11-22              2021-11-30
# 2        12759          2018-11-19              2021-11-30
# 3        11385          2018-12-31              2021-11-30
# 4        10541          2019-12-05              2021-11-30
# 5        10123          2019-12-23              2021-11-30
# 6        12010          2020-12-14              2021-11-30
# 7        94558          2018-12-03              2021-12-31
# 8        96785          2018-12-10              2021-12-31
# 9        94558          2018-12-10              2021-12-31
# 10   945159647          2018-12-07              2021-12-31
# 11       95448          2018-11-08              2021-12-31
# 12       93427          2019-06-17              2021-12-31
# 13       10024          2019-12-05              2021-12-31
# 14       10468          2019-01-10              2021-12-31
#
#                                   Method of Operation  \
# 0   HOTEL RESTAURANT SERVING BEER WINE CIDER AND L...
# 1          CATERER SERVING BEER CIDER WINE AND LIQUOR
# 2        GROCERY SELLING BEER CIDER AND WINE PRODUCTS
# 3                             WINE STORE SELLING WINE
# 4                        TAVERN SERVING BEER AND WINE
# 5             RESTAURANT SERVING WINE, BEER AND CIDER
# 6                                      WHOLESALE BEER
# 7                         OUT OF STATE DIRECT SHIPPER
# 8                         OUT OF STATE DIRECT SHIPPER
# 9                    OUT OF STATE DIRECT WINE SHIPPER
# 10                        OUT OF STATE DIRECT SHIPPER
# 11                                                NaN
# 12                                                NaN
# 13    RESTAURANT SERVING BEER, WINE, CIDER AND LIQUOR
# 14  GROCERY STORE SELLING BEER CIDER AND WINE PROD...
#
#         Days/Hours of Operation                                    Other  \
# 0                           NaN                                      NaN
# 1                           NaN                                      NaN
# 2                           NaN                                      NaN
# 3                           NaN                                      NaN
# 4                           NaN                                      NaN
# 5                           NaN  Recorded Music Permitted and No Dancing
# 6                           NaN                                      NaN
# 7                           NaN                                      NaN
# 8                           NaN                                      NaN
# 9                           NaN                                      NaN
# 10                          NaN                                      NaN
# 11                          NaN                                      NaN
# 12                          NaN                                      NaN
# 13  RECORDED MUSIC. NO DANCING.                  LICENSED SIDEWALK CAFE.
# 14                          NaN                                      NaN
#
#                              Georeference Zone  Effective Date Original Date
# 0            POINT (-73.783705 42.674761)    2      2019-12-01    1996-12-05
# 1            POINT (-73.487062 40.668214)    1      2019-12-01    2007-12-18
# 2             POINT (-74.66699 41.777859)    2      2018-12-01    2009-12-22
# 3             POINT (-73.90109 40.702673)    1      2018-12-31    2018-12-31
# 4            POINT (-73.763883 41.374319)    2      2019-12-05    2019-12-05
# 5                                     NaN    1      2019-12-23    2019-12-23
# 6              POINT (-74.1866 42.940987)    2      2020-12-14    2020-12-14
# 7    POINT (-122.33304899999999 38.40974)    2      2019-01-01    2005-10-19
# 8                                     NaN    2      2019-01-01    2007-06-28
# 9     POINT (-122.33301599999999 38.3548)    2      2019-01-01    2010-07-02
# 10   POINT (-122.54937700000002 38.57468)    2      2019-01-01    2011-08-11
# 11  POINT (-122.95010999999998 38.656503)    2      2019-01-01    2013-01-10
# 12          POINT (-120.202402 34.609092)    2      2019-06-17    2013-08-30
# 13            POINT (-73.97424 40.788753)    1      2020-01-01    2015-09-15
# 14           POINT (-73.898153 40.862681)    1      2019-01-10    2016-01-28
#
# [15 rows x 21 columns]

# %%
## get basic overview of the data
## what datatypes do the different columns hold?
## how many rows and columns are there
cbp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50140 entries, 0 to 50139
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Serial Number            50140 non-null  int64
#  1   County                   50140 non-null  object
#  2   License Type Code        50140 non-null  object
#  3   License Class Code       50140 non-null  object
#  4   Certificate Number       50140 non-null  int64
#  5   Premise Name             50139 non-null  object
#  6   DBA                      35162 non-null  object
#  7   Premise Address          50140 non-null  object
#  8   Premise Address 2        10333 non-null  object
#  9   Premise City             50140 non-null  object
#  10  Premise State            50140 non-null  object
#  11  Premise Zip              50140 non-null  object
#  12  License Issued Date      50104 non-null  datetime64[ns]
#  13  License Expiration Date  50140 non-null  datetime64[ns]
#  14  Method of Operation      49730 non-null  object
#  15  Days/Hours of Operation  5996 non-null   object
#  16  Other                    16432 non-null  object
#  17  Georeference             46674 non-null  object
#  18  Zone                     50140 non-null  int64
#  19  Effective Date           50140 non-null  datetime64[ns]
#  20  Original Date            46496 non-null  datetime64[ns]
# dtypes: datetime64[ns](4), int64(3), object(14)
# memory usage: 8.0+ MB

# %%
## call the bottom 3
cbp_df.tail(3)
# Out:
#        Serial Number    County License Type Code License Class Code  \
# 50137        2209433  ONONDAGA                AX                128
# 50138        1312336     BRONX                CM                110
# 50139        2227379    ALBANY                WS                308
#
#        Certificate Number                    Premise Name  \
# 50137              784064                    7 ELEVEN INC
# 50138              801200  TORCH & CROWN 704 BROADWAY LLC
# 50139              941478                 DUSKY GOOSE LLC
#
#                                  DBA    Premise Address   Premise Address 2  \
# 50137          SUNOCO A PLUS #40215H  1000 W GENESEE ST                 NaN
# 50138  TORCH & CROWN BREWING COMPANY     463 E 173RD ST                 NaN
# 50139                    DUSKY GOOSE  8355 NE WARREN RD  WWW.DUSKYGOOSE.COM
#
#       Premise City  ... Premise Zip License Issued Date  \
# 50137     SYRACUSE  ...       13204          2021-10-28
# 50138        BRONX  ...       10457          2021-11-08
# 50139       DUNDEE  ...       97115          2021-10-06
#
#       License Expiration Date  \
# 50137              2024-10-31
# 50138              2024-11-30
# 50139              2024-09-30
#
#                                     Method of Operation  \
# 50137  GROCERY STORE SELLING BEER CIDER & WINE PRODUCTS
# 50138                       COMBINED CRAFT MANUFACTURER
# 50139                               DIRECT WINE SHIPPER
#
#             Days/Hours of Operation                        Other  \
# 50137                           NaN                          NaN
# 50138  Micro Brewer Serial #1312333  Farm Brewer Serial #1312335
# 50139                           NaN                          NaN
#
#                         Georeference Zone  Effective Date Original Date
# 50137    POINT (-76.17092 43.053662)    2      2021-11-01    2018-02-01
# 50138   POINT (-73.901384 40.841683)    1      2021-12-01    2018-12-24
# 50139  POINT (-123.032311 45.276215)    2      2021-10-06    2021-10-06
#
# [3 rows x 21 columns]

# %%
## call a sample of 20
cbp_df.sample(20)
# Out:
#        Serial Number       County License Type Code License Class Code  \
# 25969        2506886  ST LAWRENCE                 A                122
# 37275        2013906       WARREN                AX                128
# 16108        2158112       ALBANY                WS                308
# 35213        3156231        TIOGA                OP                252
# 37444        1174595        KINGS                AX                122
# 15153        3155191      ONTARIO                OP                252
# 4947         2106323       ULSTER                OP                252
# 23789        2164092     ONONDAGA                OP                252
# 30052        3149367      STEUBEN                 A                122
# 11054        2156594       ALBANY                WS                308
# 41263        2200087       ULSTER                 L                222
# 430          1115986      SUFFOLK                AX                123
# 9582         1022414     NEW YORK                 C                103
# 32273        2210268       ALBANY                WS                308
# 44703        1254579       QUEENS                AX                122
# 39556        2500834       CAYUGA                AX                123
# 15952        1288582     NEW YORK                OP                252
# 43042        3164892   CHAUTAUQUA                 L                222
# 28197        2207001       ULSTER                OP                252
# 44310        1327036       NASSAU                AX                122
#
#        Certificate Number                        Premise Name  \
# 25969              920551             SHARLENE & SCOTT LANTRY
# 37275              845093                STEWART'S SHOPS CORP
# 16108              911685            BRICK HOUSE WINE COMPANY
# 35213              796085                         AINDARA INC
# 37444              937432              DEKALB CONVENIENCE INC
# 15153              922307                 NICKS CHOPHOUSE INC
# 4947               924222                  ZOFIA MIODUSZEWSKI
# 23789              928699           TARDIBONE ENTERPRISES LLC
# 30052              922173                  RONALD L ABBEY III
# 11054              911297                       AKA WINES LLC
# 41263              845436          JPM ENDEAVORS INCORPORATED
# 430                913048             EAST END MARKETING CORP
# 9582               939926  NEW YORK BEVERAGE WHOLESALERS CORP
# 32273              935585    CEDARVILLE VINEYARD & WINERY LLC
# 44703              933922               JR FAMILY GROCERY INC
# 39556              847156            WEGMANS FOOD MARKETS INC
# 15952              914238                       MSG ARENA LLC
# 43042              933224                     NAKED GRACE LLC
# 28197              920250               WHO COOKS FOR YOU LLC
# 44310              933366                      PRAGAT 197 INC
#
#                                                 DBA  \
# 25969                          HELENA GENERAL STORE
# 37275                           STEWART'S SHOP #282
# 16108                                           NaN
# 35213  ORIGINAL ITALIAN PIZZA & RESTAURANT OF OWEGO
# 37444                            DEKALB CONVENIENCE
# 15153                                           NaN
# 4947                               RUNNING DEER INN
# 23789                                   KEGS & EGGS
# 30052                             BEARTOWN BEVERAGE
# 11054                                 SCRIBE WINERY
# 41263                      MALONEY'S WINES & LIQUOR
# 430                      WEST HAMPTON BEACH COASTAL
# 9582                                            NaN
# 32273                           CEDARVILLE VINEYARD
# 44703                                           NaN
# 39556                                       WEGMANS
# 15952                         MADISON SQUARE GARDEN
# 43042                            B K WINE & SPIRITS
# 28197                                      HOOT OWL
# 44310                                    CIGAR SHOP
#
#                      Premise Address Premise Address 2        Premise City  \
# 25969                     28 MAIN ST               NaN              HELENA
# 37275              977 STATE RTE 149               NaN          QUEENSBURY
# 16108        18200 LEWIS ROGERS LANE               NaN             NEWBERG
# 35213                     25 LAKE ST               NaN               OWEGO
# 37444                 249 DEKALB AVE               NaN            BROOKLYN
# 15153  3-7 BEEMAN ST AND 195 MAIN ST               NaN         CANANDAIGUA
# 4947                28 ROUTE 55 WEST               NaN            NAPANOCH
# 23789        7 NORTH HAMILTON STREET               NaN              JORDAN
# 30052                3 BEARTOWN ROAD               NaN        PAINTED POST
# 11054       21684 EIGHTH STREET EAST               NaN              SONOMA
# 41263                    3139 RTE 9W            UNIT 8          SAUGERTIES
# 430                  112 MONTAUK HWY               NaN  WEST HAMPTON BEACH
# 9582               515 BRUCKNER BLVD               NaN               BRONX
# 32273              6320 MARESTAIL RD               NaN           FAIR PLAY
# 44703                 39 02 104TH ST               NaN              CORONA
# 39556                    1 LOOP ROAD               NaN              AUBURN
# 15952           4 PENNSYLVANIA PLAZA               NaN            NEW YORK
# 43042                  107 W MAIN ST               NaN             SHERMAN
# 28197                 26 AWOSTING RD               NaN           PINE BUSH
# 44310               197 FRANKLIN AVE               NaN     FRANKLIN SQUARE
#
#        ... Premise Zip License Issued Date License Expiration Date  \
# 25969  ...       13649          2019-08-16              2022-09-30
# 37275  ...       12804          2021-06-01              2024-07-31
# 16108  ...       97132          2018-12-19              2021-12-31
# 35213  ...       13827          2021-06-10              2023-06-30
# 37444  ...       11205          2021-03-17              2024-04-30
# 15153  ...       14424          2020-06-16              2022-07-31
# 4947   ...       12458          2020-07-21              2022-07-31
# 23789  ...       13080          2020-11-23              2022-12-31
# 30052  ...       14870          2019-11-06              2022-11-30
# 11054  ...       95476          2018-12-10              2021-12-31
# 41263  ...       12477          2021-06-08              2024-07-31
# 430    ...       11978          2019-02-01              2022-03-31
# 9582   ...       10455          2021-04-21              2022-06-30
# 32273  ...       95684          2020-12-14              2023-11-30
# 44703  ...       11368          2020-08-21              2023-08-31
# 39556  ...       13021          2021-06-30              2024-06-30
# 15952  ...       10121          2020-01-15              2022-01-31
# 43042  ...       14781          2020-08-31              2023-07-31
# 28197  ...       12566          2021-03-31              2023-03-31
# 44310  ...       11010          2020-09-17              2023-08-31
#
#                                      Method of Operation  \
# 25969            GROCERY STORE SELLING BEER & CIDER ONLY
# 37275  CONVENIENCE STORE SELLING BEER, CIDER AND WINE...
# 16108                        OUT OF STATE DIRECT SHIPPER
# 35213      RESTAURANT SERVING BEER CIDER WINE AND LIQUOR
# 37444  GROCERY STORE SELLING BEER CIDER AND WINE PRODUCT
# 15153     RESTAURANT SERVING LIQUOR, BEER, WINE, & CIDER
# 4947           TAVERN SERVING BEER WINE CIDER AND LIQUOR
# 23789     RESTAURANT SERVING BEER, WINE, LIQUOR, & CIDER
# 30052                 GROCERY STORE SELLING BEER & CIDER
# 11054                        OUT OF STATE DIRECT SHIPPER
# 41263                                       LIQUOR STORE
# 430    GROCERY STORE SELLING BEER CIDER AND WINE PROD...
# 9582                                      WHOLESALE BEER
# 32273                                DIRECT WINE SHIPPER
# 44703  GROCERY STORE SELLING BEER, CIDER AND WINE PRO...
# 39556  GROCERY STORE SELLING BEER CIDER AND WINE PROD...
# 15952         ARENA SERVING BEER, CIDER, WINE AND LIQUOR
# 43042               LIQUOR STORE SELLING WINE AND LIQUOR
# 28197        RESTAURANT SERVING BEER WINE CIDER & LIQUOR
# 44310  GROCERY STORE SELLING BEER, WINE PRODUCTS & CIDER
#
#        Days/Hours of Operation  \
# 25969                      NaN
# 37275                      NaN
# 16108                      NaN
# 35213                      NaN
# 37444                      NaN
# 15153  Live and Recorded Music
# 4947                       NaN
# 23789                      NaN
# 30052                      NaN
# 11054                      NaN
# 41263                      NaN
# 430                        NaN
# 9582                       NaN
# 32273                      NaN
# 44703                      NaN
# 39556                      NaN
# 15952       LEVEL 2 GOLD BAR A
# 43042                      NaN
# 28197                      NaN
# 44310                      NaN
#
#                                                    Other  \
# 25969                                                NaN
# 37275                                                NaN
# 16108                                                NaN
# 35213                                                NaN
# 37444                                                NaN
# 15153                   Licensed Sidewalk Cafe & Rooftop
# 4947                                                 NaN
# 23789  Music & Dancing Permitted, Licensed Yard/Pavil...
# 30052                                                NaN
# 11054                                                NaN
# 41263                                                NaN
# 430                                                  NaN
# 9582                                                 NaN
# 32273                                                NaN
# 44703                                                NaN
# 39556                                                NaN
# 15952                                         Live music
# 43042                                                NaN
# 28197                 Recorded/Live Music; Sidewalk Cafe
# 44310                                                NaN
#
#                                 Georeference Zone  Effective Date  \
# 25969           POINT (-74.893079 44.932522)    2      2019-10-01
# 37275                                    NaN    2      2021-08-01
# 16108          POINT (-123.072439 45.347721)    2      2019-01-01
# 35213           POINT (-76.261226 42.103138)    3      2021-07-01
# 37444           POINT (-73.969337 40.689475)    1      2021-05-01
# 15153                                    NaN    3      2020-08-01
# 4947                                     NaN    2      2020-08-01
# 23789           POINT (-76.477131 43.067127)    2      2021-01-01
# 30052           POINT (-77.111435 42.146344)    3      2019-12-01
# 11054          POINT (-122.440441 38.260169)    2      2019-01-01
# 41263           POINT (-73.954787 42.057142)    2      2021-08-01
# 430             POINT (-72.646466 40.821822)    1      2019-04-01
# 9582            POINT (-73.902157 40.810511)    1      2021-07-01
# 32273  POINT (-120.67316399999999 38.597214)    2      2020-12-14
# 44703                                    NaN    1      2020-09-01
# 39556           POINT (-76.563976 42.930818)    2      2021-07-01
# 15952                                    NaN    1      2020-02-01
# 43042           POINT (-79.597339 42.159327)    3      2020-08-31
# 28197           POINT (-74.264175 41.648687)    2      2021-04-01
# 44310           POINT (-73.678992 40.702704)    1      2020-09-17
#
#       Original Date
# 25969    2004-11-22
# 37275           NaT
# 16108    2010-03-23
# 35213    2015-07-08
# 37444    2006-05-02
# 15153    2014-08-19
# 4947     2017-04-19
# 23789    2011-01-11
# 30052    2010-12-08
# 11054    2010-02-01
# 41263    2015-08-07
# 430             NaT
# 9582     1996-05-30
# 32273    2017-12-04
# 44703    2011-09-20
# 39556    2002-09-05
# 15952    2016-02-23
# 43042    2020-08-31
# 28197    2017-04-13
# 44310    2020-09-17
#
# [20 rows x 21 columns]

# %%
## Programmatically capture the 8th hours_in_custody value and store in a variable.

# %%
hours = cbp_df.iloc[7]["hours_in_custody"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hours_in_custody'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 hours = cbp_df.iloc[7]["hours_in_custody"]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'hours_in_custody'
